# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import Image
iris = sns.load_dataset("iris")

# %%
# Fixing random state for reproducibility
np.random.seed(19680801)
x = np.random.rand(10)
y = np.random.rand(10)
z = np.sqrt(x**2 + y**2)

# %% [markdown]
# # [plt.subplot]그래프 여러개를 한번에 나타내고싶어!

# %%
plt.subplot(221)
plt.scatter(x, y, s=80, c=z, marker=">")

plt.subplot(222)
plt.scatter(x, y, s=80, c=z, marker='+')

verts = np.array([[-1, -1], [1, -1], [1, 1], [-1, -1]])
plt.subplot(223)
plt.scatter(x, y, s=80)

plt.subplot(224)
plt.scatter(x, y, s=80, c='red')

plt.show()
# jupyter 에서는 그닥 plt.show() 가 default 값이라 필요는 없다.

# %% [markdown]
# plt.subplot(221) 의 의미는 2*2 matrix 의 제일 첫번째 graph 라는 의미. 채우는 순서는 row 부터 채운다.
#
# plt.subplot(321) 로 하게되면 3*2 matrix 의 격자가 형성된다

# %% [markdown]
# # [plt.figure(figsize=())]그래프 크기조절

# %%
plt.figure(figsize=(20,5))
#plt.figure(figsize=(20,5)) 로 설정하게되면 figure 의 크기가 늘어나게 된다.

plt.subplot(221)
plt.scatter(x, y, s=80, c=z, marker=">")

plt.subplot(222)
plt.scatter(x, y, s=80, c=z, marker='+')

verts = np.array([[-1, -1], [1, -1], [1, 1], [-1, -1]])
plt.subplot(223)
plt.scatter(x, y, s=80)

plt.subplot(224)
plt.scatter(x, y, s=80, c='red')

# %% [markdown]
# # [plt.(s,c,marker,alpha)]그래프 점 모양/색깔/크기/투명도 조절

# %%
plt.scatter(x, y, s=80, c='b', marker='+',alpha=0.3) 
#이때에 s가 점의 크기, c가 색깔 marker 가 모양을,alpha 는 투명도를 나타낸다.

# %%
Image("C:/Users/Han/Desktop/Statistics/Python/Tools/Visualization/Pictures/plt_dotstyle.JPG")

# %%
Image("C:/Users/Han/Desktop/Statistics/Python/Tools/Visualization/Pictures/plt_linestyle.JPG")

# %%
Image("C:/Users/Han/Desktop/Statistics/Python/Tools/Visualization/Pictures/plt_colorstyle.JPG")

# %%
x = np.linspace(0, 10, 50)
dy = 0.8
y = np.sin(x) + dy * np.random.randn(50)

plt.errorbar(x, y, yerr=dy, fmt=':or'); 
#fmt 는 모양,색깔,그래프style 을 한번에 지정해주는 method 이다

# %% [markdown]
# # [plt.cmap/colorbar] gradient 색깔지정

# %%
Image("C:/Users/Han/Desktop/Statistics/Python/Tools/Visualization/Pictures/plt_colormap.JPG")

# %%
Image("C:/Users/Han/Desktop/Statistics/Python/Tools/Visualization/Pictures/plt_colormap 2ways.JPG")

# %%
Image("C:/Users/Han/Desktop/Statistics/Python/Tools/Visualization/Pictures/plt_colormap_discrete.JPG")

# %%
def f(x, y):
    return np.sin(x) ** 10 + np.cos(10 + y * x) * np.cos(x)
x = np.linspace(0, 5, 50)
y = np.linspace(0, 5, 40)
X, Y = np.meshgrid(x, y)
Z = f(X, Y)

plt.contourf(X, Y, Z, levels=20, cmap='RdGy')
plt.colorbar(label='values')# colorbar 를 옆에 붙이자!
# label 을 붙이면 colorbar 의 이름을 넣게된다.
plt.clim(-0.5,1 )# color 의 범위를 설정한다. -0.5 일때 최대 color 를 표출하게된다.

# %%
plt.contourf(X, Y, Z, levels=20,cmap = plt.cm.get_cmap('RdBu', 6)) # 이렇게 지정하게되면, cmap 이 discrete 하게 들어간다.
plt.colorbar(label='values')
plt.clim(-0.5,1)

# %% [markdown]
#  # [plt.xlabel/ylabel/title] 그래프 제목,x축,y축 이름지정

# %%
data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

plt.scatter('a', 'b', c='c', s='d', data=data) # 이렇게 하면 크기가 random 으로 들어가게된다
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.title('Inwook practice')
# plt 를 그린 후, plt.title,plt.xlabel plt.ylabel 을 추가해주면 된다.
plt.show()

# %% [markdown]
# # [plt.xticks/yticks] x,y 축에 label 하기

# %%
plt.scatter('a', 'b', c='c', s='d', data=data)
plt.xticks([0,10,20,30,40,50],['Look','Sam','Tom', 'Dick', 'Sue','Go'],rotation=60);
# 앞은 는 어느곳에 label 할 것인지.
# 뒤는 는 어떤 label 을 매길지
# rotation 은 회전시키는 정도

# %% [markdown]
# # [plt.xlim/ylim] x 축, y 축의 범위를 설정

# %%
data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

plt.scatter('a', 'b', c='c', s='d', data=data)
plt.ylim(-10,10)
# 이렇게 설정하면 -10 ~10 의 ylim 으로 설정이 된다.
plt.show()

# %% [markdown]
# # [plt.gca().invert_] x,y 축 order 변경

# %%
plt.scatter('a', 'b', c='c', s='d', data=data)
plt.gca().invert_yaxis()# 이렇게 하면 y 축이 작은것부터 형성됨을 알 수 이다.
#plt.gca().invert_xaxis() # 이것은 x 축 역수로

# %% [markdown]
# # [plt. +plt....] plt 를 겹쳐그리고싶어!

# %%
def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)


plt.plot(t1,f(t1),'bo')
plt.plot(t2,f(t2),'k')
# plt.plot 을 여러번 지정해주면 된다.

# %% [markdown]
# # [plt.text]그래프 안에 text 를 넣기

# %%
mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)

# the histogram of the data
n, bins, patches = plt.hist(x, 50, density=1, facecolor='g', alpha=0.75)
# plt.text(60, .025, r'$\mu=100, \sigma=15$') 이렇게 plt.text 를 쓰면 된다. 60,.025 는 각 x,y 의 위치이다.)
plt.text(60, .025, r'$\mu=100, \sigma=15$')  # markdown 문법을 사용한 모습.
plt.axis([40, 160, 0, 0.03]) 
plt.show()

# %% [markdown]
# # [plt.grid(True)]그래프를 격자형태로 만들어주고싶어

# %%
mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)

# the histogram of the data
n, bins, patches = plt.hist(x, 50, density=1, facecolor='g', alpha=0.75)

plt.text(60, .025, r'$\mu=100, \sigma=15$')  # markdown 문법을 사용한 모습.
plt.axis([40, 160, 0, 0.03]) 
plt.grid(True)
#plt.grid(True) 를 넣게되면 격자를 형성하게 된다. 
plt.show()

# %% [markdown]
# # [plt.annotate] 화살표로 특정 지점을 가르키기

# %%
t = np.arange(0.0, 5.0, 0.01)
s = np.cos(2*np.pi*t)
line, = plt.plot(t, s, lw=2)

plt.annotate('local max', xy=(2, 1), xytext=(3, 1.5),arrowprops= dict(facecolor='black'),)
# xy=(a,b) 는 a,b 지점에 화살표의 꼭지점이 표시된다는 의미
# xytest(a,b) 는 a,b 지점에 text 를 적겠다는 의미
plt.ylim(-2, 2)
plt.show()

# %% [markdown]
# # [plt.legend]범례(legend) 를 표시하고 싶어!

# %%
X = np.linspace(-np.pi, np.pi, 256)
C, S = np.cos(X), np.sin(X)
plt.title("legend plot")
plt.plot(X, C, ls="--", label="cosine")
plt.plot(X, S, ls=":", label="sine")
plt.legend(loc=2)
#legend 를 하려면 plt.plot 시에 label 을 붙여줘야 됨을 명심하자.
#loc 은 legend 의 location 이다. 자세한건 elementary file 에.
plt.show()

# %% [markdown]
# # [with plt.xkcd():]그래프를 손그림처럼 나타내고싶어

# %%
with plt.xkcd():
    X = np.linspace(-np.pi, np.pi, 256)
    C, S = np.cos(X), np.sin(X)
    plt.title("legend plot")
    plt.plot(X, C, ls="--", label="cosine")
    plt.plot(X, S, ls=":", label="sine")
    plt.legend(loc=2)
    plt.show()
# with plt.xkcd(): 이걸 널어주니까 그래프가 동글동글 이쁘다!

# %% [markdown]
# # [plt.savefig]그래프를 저장하고싶어!

# %%
X = np.linspace(-np.pi, np.pi, 256)
C, S = np.cos(X), np.sin(X)

plt.title("legend plot")
plt.plot(X, C, ls="--", label="cosine")
plt.plot(X, S, ls=":", label="sine")
plt.legend(loc=2)
plt.savefig('example.png') #이러면 figure 을 저장하게된다. 저장경로는 ipynb 가 있는 위치

# %% [markdown]
# # 객체로 편하게 subplot을 지정하자!

# %%
fig, ax = plt.subplots(nrows=2,ncols=3) 
#plt.subplot 의 obtion
#sharex : Xtick의 값을 각각 공유할지 안할지 ,sharey : Ytick의 값을 각각 공유할지 안할지
#figsize : plot 의 size 
#facecolor : subplots 의 색깔
ax[0,1].plot(X, C, ls="--", label="cosine") # ax[0,1] 위치에 plot

# %%
fig, [[ax1, ax2], [ax3, ax4]] = plt.subplots(figsize=(6,3),facecolor='bisque',nrows=2, ncols=2)
ax1.plot(X, S, ls=":", label="sine")
good=fig
good

# %%
# fig 는 fig 에 쓰= plt.figure() 이고, ax 는 suplot 의 역할이다. 
# fig, ax = plt.subplots(nrows=2,ncols=3) 를 하는순간, 우리는 subplot 에서 fig 와 ax 를 unpack 하게 되는데, 이렇게 unpack 하고나면
# 우리가 그리고싶은 plot 앞는것 만으로도 설정을 그대로 옮겨가게 된다.
# ax 를 쓰면 #1 의 예제처럼 plt.subplot 을 마구잡이로 쓰지 않아도 된다
# fig 는 fig.savefig('yourfilename.png') 처럼 우리가 만든 그래프를 저장하거나 plot_normal=fig 처럼 지정하는것 등에 편하다.

# %% [markdown]
# # 그래프 여러개의 x,y 범위를 동일하게 하고싶어!

# %%
fig, ax = plt.subplots(nrows=2,ncols=3,sharey=True) 
#sharex : Xtick의 값을 각각 공유할지 안할지 ,sharey : Ytick의 값을 각각 공유할지 안할지

# %% [markdown]
#  # 객체로 graph 의 기본설정을 편하게 지정하자

# %%
fig = plt.figure()
ax = plt.axes()

# %% [markdown]
# In Matplotlib, the *figure* (an instance of the class ``plt.Figure``) can be thought of as a single container that contains all the objects representing axes, graphics, text, and labels.
#
# The *axes* (an instance of the class ``plt.Axes``) is what we see above: a bounding box with ticks and labels, which will eventually contain the plot elements that make up our visualization.

# %% [markdown]
# - ``plt.xlabel()``  → ``ax.set_xlabel()``
# - ``plt.ylabel()`` → ``ax.set_ylabel()``
# - ``plt.xlim()``  → ``ax.set_xlim()``
# - ``plt.ylim()`` → ``ax.set_ylim()``
# - ``plt.title()`` → ``ax.set_title()``

# %%
x = np.linspace(0, 10, 1000)
ax = plt.axes()
ax.plot(x, np.sin(x))
ax.set(xlim=(0, 10), ylim=(-2, 2),
       xlabel='x', ylabel='sin(x)',
       title='A Simple Plot');
# 이렇게 하면 계속 plt.xlim ... 을 하지 않아도 된다.
